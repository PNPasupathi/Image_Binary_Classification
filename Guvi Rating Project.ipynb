# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'guvi.csv')

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    41295.0               Learn HTML5 Programming From Scratch
# 1    59014.0                     Coding for Entrepreneurs Basic
# 2   625204.0                         The Web Developer Bootcamp
# 3   173548.0  Build Your First Website in 1 Week with HTML5 ...
# 4   764164.0              The Complete Web Developer Course 2.0
#
#                                                  url  price  num_subscribers  \
# 0  https://www.udemy.com/learn-html5-programming-...    0.0         268923.0
# 1  https://www.udemy.com/coding-for-entrepreneurs...    0.0         161029.0
# 2  https://www.udemy.com/the-web-developer-bootcamp/  200.0         121584.0
# 3  https://www.udemy.com/build-your-first-website...    0.0         120291.0
# 4  https://www.udemy.com/the-complete-web-develop...  200.0         114512.0
#
#    num_reviews  num_lectures           level  Rating  content_duration  \
# ...

# %%
df=df[['price','num_subscribers','num_reviews','num_lectures','level','Rating','content_duration','published_timestamp','subject']]

# %%
df.head()
# Out:
#    price  num_subscribers  num_reviews  num_lectures           level  Rating  \
# 0    0.0         268923.0       8629.0          45.0  Beginner Level    0.82
# 1    0.0         161029.0        279.0          27.0    Expert Level    0.69
# 2  200.0         121584.0      27445.0         342.0  Beginner Level    0.89
# 3    0.0         120291.0       5924.0          30.0      All Levels    0.78
# 4  200.0         114512.0      22412.0         304.0  Beginner Level    0.55
#
#    content_duration   published_timestamp                   subject
# 0              10.5  2013-02-14T07:03:41Z  Subject: Web Development
# 1               3.5  2013-06-09T15:51:55Z  Subject: Web Development
# 2              43.0  2015-11-02T21:13:27Z  Subject: Web Development
# 3               3.0  2014-04-08T16:21:30Z  Subject: Web Development
# 4              30.5  2016-03-08T22:28:36Z  Subject: Web Development

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3680 entries, 0 to 3679
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   price                3676 non-null   float64
#  1   num_subscribers      3676 non-null   float64
#  2   num_reviews          3676 non-null   float64
#  3   num_lectures         3676 non-null   float64
#  4   level                3676 non-null   object
#  5   Rating               3676 non-null   float64
#  6   content_duration     3676 non-null   float64
#  7   published_timestamp  3676 non-null   object
#  8   subject              3677 non-null   object
# dtypes: float64(6), object(3)
# memory usage: 258.9+ KB

# %%
df.isnull().sum()
# Out:
# price                  4
# num_subscribers        4
# num_reviews            4
# num_lectures           4
# level                  4
# Rating                 4
# content_duration       4
# published_timestamp    4
# subject                3
# dtype: int64

# %%
df.dropna(inplace=True,axis=0)

# %%
df.isnull().sum()
# Out:
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# Rating                 0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#              price  num_subscribers   num_reviews  num_lectures       Rating  \
# count  3676.000000      3676.000000   3676.000000   3676.000000  3676.000000
# mean     66.115343      3199.260881    156.309848     40.129761     0.610868
# std      61.056073      9486.582966    935.674518     50.398507     0.334287
# min       0.000000         0.000000      0.000000      0.000000     0.000000
# 25%      20.000000       112.000000      4.000000     15.000000     0.280000
# 50%      45.000000       912.500000     18.000000     25.000000     0.760000
# 75%      95.000000      2558.000000     67.000000     46.000000     0.930000
# max     200.000000    268923.000000  27445.000000    779.000000     1.000000
#
#        content_duration
# count       3676.000000
# mean           4.096137
# std            6.054948
# min            0.000000
# 25%            1.000000
# 50%            2.000000
# 75%            4.500000
# max           78.500000

# %%
df['level'].value_counts()
# Out:
# All Levels            1925
# Beginner Level        1271
# Intermediate Level     422
# Expert Level            58
# Name: level, dtype: int64

# %%
df['subject'].value_counts()
# Out:
# Subject: Web Development    1203
# Business Finance            1191
# Musical Instruments          680
# Graphic Design               602
# Name: subject, dtype: int64

# %%
sns.scatterplot(data=df,x='price',y='Rating')
df[['price','Rating']].corr()
# Out:
#            price    Rating
# price   1.000000  0.031643
# Rating  0.031643  1.000000

# %%
sns.scatterplot(data=df,x='num_subscribers',y='Rating')
df[['num_subscribers','Rating']].corr()
# Out:
#                  num_subscribers    Rating
# num_subscribers         1.000000 -0.007353
# Rating                 -0.007353  1.000000

# %%
sns.scatterplot(data=df,x='num_reviews',y='Rating')
df[['num_reviews','Rating']].corr()
# Out:
#              num_reviews    Rating
# num_reviews     1.000000  0.004137
# Rating          0.004137  1.000000

# %%
sns.scatterplot(data=df,x='content_duration',y='Rating')
df[['content_duration','Rating']].corr()
# Out:
#                   content_duration   Rating
# content_duration           1.00000  0.00065
# Rating                     0.00065  1.00000

# %%
df['published_timestamp']=df['published_timestamp'].apply(lambda x: x.split('-')[0])

# %%
sns.scatterplot(data=df,x='published_timestamp',y='Rating')
df[['published_timestamp','Rating']].corr()
# Out:
#         Rating
# Rating     1.0

# %% [markdown]
# ### Encoding

# %%
df['level'].unique()
# Out:
# array(['Beginner Level', 'Expert Level', 'All Levels',
#        'Intermediate Level'], dtype=object)

# %%
df['level']=df['level'].map({"Beginner Level":0,"Intermediate Level":1,"All Levels":2,"Expert Level":4})

# %%
sns.scatterplot(data=df,x='level',y='Rating')
df[['level','Rating']].corr()
# Out:
#            level    Rating
# level   1.000000  0.024904
# Rating  0.024904  1.000000
